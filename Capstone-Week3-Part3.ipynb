# %% [markdown]
# # Capstone Week 3 Part 3

# %% [markdown]
# #### Importing the library

# %%
import pandas as pd

# %% [markdown]
# #### Scraping the wiki to get the data

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
df.head(12)
# Out:
#    Postcode           Borough     Neighbourhood
# 0       M1A      Not assigned      Not assigned
# 1       M2A      Not assigned      Not assigned
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M6A        North York  Lawrence Heights
# 6       M6A        North York    Lawrence Manor
# 7       M7A  Downtown Toronto      Queen's Park
# 8       M8A      Not assigned      Not assigned
# 9       M9A      Queen's Park      Not assigned
# 10      M1B       Scarborough             Rouge
# 11      M1B       Scarborough           Malvern

# %% [markdown]
# #### Renaming the column postal code as shown and correcting the spelling of Neighborhood. This is not the band.

# %%
df.rename(columns={'Postcode':'PostalCode', 'Neighbourhood':'Neighborhood'}, inplace=True)
df.head(1)
# Out:
#   PostalCode       Borough  Neighborhood
# 0        M1A  Not assigned  Not assigned

# %% [markdown]
# #### Removing rows where **Borough** is **Not assigned**

# %%
badrows = df[df['Borough']=='Not assigned'].index
df.drop(badrows, inplace=True)
df.head(12)
# Out:
#    PostalCode           Borough      Neighborhood
# 2         M3A        North York         Parkwoods
# 3         M4A        North York  Victoria Village
# 4         M5A  Downtown Toronto      Harbourfront
# 5         M6A        North York  Lawrence Heights
# 6         M6A        North York    Lawrence Manor
# 7         M7A  Downtown Toronto      Queen's Park
# 9         M9A      Queen's Park      Not assigned
# 10        M1B       Scarborough             Rouge
# 11        M1B       Scarborough           Malvern
# 13        M3B        North York   Don Mills North
# 14        M4B         East York  Woodbine Gardens
# 15        M4B         East York     Parkview Hill

# %% [markdown]
# #### Copying the Borough name to the Neighborhood for the, If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough requirement.

# %%
df.loc[df['Neighborhood']=='Not assigned','Neighborhood'] = df.loc[df['Neighborhood']=='Not assigned'].Borough
df.head(12)
# Out:
#    PostalCode           Borough      Neighborhood
# 2         M3A        North York         Parkwoods
# 3         M4A        North York  Victoria Village
# 4         M5A  Downtown Toronto      Harbourfront
# 5         M6A        North York  Lawrence Heights
# 6         M6A        North York    Lawrence Manor
# 7         M7A  Downtown Toronto      Queen's Park
# 9         M9A      Queen's Park      Queen's Park
# 10        M1B       Scarborough             Rouge
# 11        M1B       Scarborough           Malvern
# 13        M3B        North York   Don Mills North
# 14        M4B         East York  Woodbine Gardens
# 15        M4B         East York     Parkview Hill

# %% [markdown]
# #### I use a groupby to combine redundant postal codes and apply a list for each neighborhood. I then use a join to convert eash neighborhood list into a comma delimited string for each row.

# %%
df = df.groupby(['PostalCode','Borough'], sort=False, as_index=True)['Neighborhood'].apply(list).reset_index(drop=False)
df['Neighborhood'] = df['Neighborhood'].apply(', '.join)
df.head(12)
# Out:
#    PostalCode           Borough  \
# 0         M3A        North York
# 1         M4A        North York
# 2         M5A  Downtown Toronto
# 3         M6A        North York
# 4         M7A  Downtown Toronto
# 5         M9A      Queen's Park
# 6         M1B       Scarborough
# 7         M3B        North York
# 8         M4B         East York
# 9         M5B  Downtown Toronto
# 10        M6B        North York
# 11        M9B         Etobicoke
#
#                                          Neighborhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                                        Harbourfront
# 3                    Lawrence Heights, Lawrence Manor
# 4                                        Queen's Park
# 5                                        Queen's Park
# 6                                      Rouge, Malvern
# 7                                     Don Mills North
# 8                     Woodbine Gardens, Parkview Hill
# 9                            Ryerson, Garden District
# 10                                          Glencairn
# 11  Cloverdale, Islington, Martin Grove, Princess ...

# %% [markdown]
# #### This is the shape of the dataframe.

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Getting the CSV data for Question 2

# %%
df1 = pd.read_csv('Geospatial_Coordinates.csv')
df1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# #### Checking the shape

# %%
df1.shape
# Out:
# (103, 3)

# %% [markdown]
# #### Pre-processing, fixing the column header so it matches the or dataframe and can be used as a key to match the rows in a join.

# %%
df1.rename(columns={'Postal Code':'PostalCode'}, inplace=True)
df1.head(1)
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353

# %% [markdown]
# #### In SQL this is a LEFT JOIN, more info on https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html for doing it in pandas. Using validate to check for duplicate keys.

# %%
result = pd.merge(df, df1, how='left', on=['PostalCode'], validate="one_to_one")
result.head(12)
# Out:
#    PostalCode           Borough  \
# 0         M3A        North York
# 1         M4A        North York
# 2         M5A  Downtown Toronto
# 3         M6A        North York
# 4         M7A  Downtown Toronto
# 5         M9A      Queen's Park
# 6         M1B       Scarborough
# 7         M3B        North York
# 8         M4B         East York
# 9         M5B  Downtown Toronto
# 10        M6B        North York
# 11        M9B         Etobicoke
#
#                                          Neighborhood   Latitude  Longitude
# 0                                           Parkwoods  43.753259 -79.329656
# 1                                    Victoria Village  43.725882 -79.315572
# 2                                        Harbourfront  43.654260 -79.360636
# 3                    Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                        Queen's Park  43.662301 -79.389494
# 5                                        Queen's Park  43.667856 -79.532242
# 6                                      Rouge, Malvern  43.806686 -79.194353
# 7                                     Don Mills North  43.745906 -79.352188
# 8                     Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                            Ryerson, Garden District  43.657162 -79.378937
# 10                                          Glencairn  43.709577 -79.445073
# 11  Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724

# %%
import folium
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans
# %matplotlib inline

# %%
map_toronto = folium.Map(location=[43.6532, -79.3832], zoom_start=10)

for lat, lng, borough, neighborhood in zip(result['Latitude'], result['Longitude'], result['Borough'], result['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## For question 3 I decieded to use k-means to cluster areas based on thier homicide data to see in which areas you would be more likely shot, stabbed, or other. I went to the toronto police database to pull the data. see below.

# %%
#Toronto Homicide Data
#http://data.torontopolice.on.ca/datasets/homicide-1
df2 = pd.read_csv('Homicide.csv')
df2.head(12)
# Out:
#             X          Y  Index_ Event_Unique_ID  Occurrence_year Division  \
# 0  -79.386620  43.648640     201         1787320             2006      D52
# 1  -79.304939  43.715988     202         1470621             2006      D54
# 2  -79.304939  43.715988     203         1470621             2006      D54
# 3  -79.228691  43.809391     204         1448992             2006      D42
# 4  -79.484482  43.649334     205         1945800             2006      D11
# 5  -79.393929  43.642738     206         1796411             2006      D14
# 6  -79.197136  43.796772     207         1462848             2006      D42
# 7  -79.358688  43.662418     208         1451923             2006      D51
# 8  -79.427376  43.638962     209         1501929             2006      D14
# 9  -79.573471  43.725754     210         1490523             2006      D23
# 10 -79.518822  43.761921     211         1932560             2006      D31
# 11 -79.560150  43.647400     212         1904938             2006      D22
#
#    Homicide_Type           Occurrence_Date  Hood_ID  \
# 0       Shooting  2006-10-27T04:00:00.000Z       77
# 1       Stabbing  2006-11-05T05:00:00.000Z       43
# 2       Stabbing  2006-11-05T05:00:00.000Z       43
# 3       Shooting  2006-11-14T05:00:00.000Z      132
# 4          Other  2006-11-25T05:00:00.000Z       87
# 5       Shooting  2006-12-03T05:00:00.000Z       77
# 6          Other  2006-12-03T05:00:00.000Z      132
# 7          Other  2006-12-20T05:00:00.000Z       72
# 8       Shooting  2006-12-25T05:00:00.000Z       85
# 9       Stabbing  2006-12-26T05:00:00.000Z        4
# 10      Shooting  2006-12-27T05:00:00.000Z       24
# 11         Other  2006-10-06T04:00:00.000Z       14
#
#                              Neighbourhood        Lat       Long  ObjectId
# 0   Waterfront Communities-The Island (77)  43.648640 -79.386620         1
# 1                    Victoria Village (43)  43.715988 -79.304939         2
# 2                    Victoria Village (43)  43.715988 -79.304939         3
# 3                            Malvern (132)  43.809391 -79.228691         4
# 4                   High Park-Swansea (87)  43.649334 -79.484482         5
# 5   Waterfront Communities-The Island (77)  43.642738 -79.393929         6
# 6                            Malvern (132)  43.796772 -79.197136         7
# 7                         Regent Park (72)  43.662418 -79.358688         8
# 8                      South Parkdale (85)  43.638962 -79.427376         9
# 9                      Rexdale-Kipling (4)  43.725754 -79.573471        10
# 10                        Black Creek (24)  43.761921 -79.518822        11
# 11         Islington-City Centre West (14)  43.647400 -79.560150        12

# %%
# filter columns
filtered_columns = df2[['Neighbourhood', 'Homicide_Type', 'Lat', 'Long']]
filtered_columns.rename(columns={'Neighbourhood':'Neighborhood'}, inplace=True)
# Out:
# c:\users\knigh\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
filtered_columns
# Out:
#                                 Neighborhood Homicide_Type        Lat  \
# 0     Waterfront Communities-The Island (77)      Shooting  43.648640
# 1                      Victoria Village (43)      Stabbing  43.715988
# 2                      Victoria Village (43)      Stabbing  43.715988
# 3                              Malvern (132)      Shooting  43.809391
# 4                     High Park-Swansea (87)         Other  43.649334
# ...                                      ...           ...        ...
# 1088                          Moss Park (73)      Stabbing  43.658295
# 1089                Etobicoke West Mall (13)      Shooting  43.639656
# 1090                     Eglinton East (138)      Shooting  43.741611
# 1091                           Malvern (132)      Shooting  43.810932
# 1092            Tam O'Shanter-Sullivan (118)      Stabbing  43.783596
#
#            Long
# 0    -79.386620
# 1    -79.304939
# 2    -79.304939
# 3    -79.228691
# 4    -79.484482
# ...         ...
# 1088 -79.371033
# 1089 -79.562935
# 1090 -79.239731
# 1091 -79.227135
# 1092 -79.299347
#
# [1093 rows x 4 columns]

# %%
import string
filtered_columns['Neighborhood'] = filtered_columns['Neighborhood'].str.strip("()")
filtered_columns['Neighborhood'] = filtered_columns['Neighborhood'].str.strip(string.digits)
filtered_columns['Neighborhood'] = filtered_columns['Neighborhood'].str.strip(" ()")
# Out:
# c:\users\knigh\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\knigh\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\knigh\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
filtered_columns.Homicide_Type.unique()
# Out:
# array(['Shooting', 'Stabbing', 'Other'], dtype=object)

# %%
map_toronto = folium.Map(location=[43.6532, -79.3832], zoom_start=10)

for lat, lng, borough, Neighborhood in zip(filtered_columns['Lat'], filtered_columns['Long'], filtered_columns['Homicide_Type'], filtered_columns['Neighborhood']):
    label = '{}, {}'.format(Neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=2,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
filtered_columns.groupby('Neighborhood').count()
# Out:
#                               Homicide_Type  Lat  Long
# Neighborhood
# Agincourt North                           5    5     5
# Agincourt South-Malvern West              6    6     6
# Alderwood                                 6    6     6
# Annex                                     7    7     7
# Banbury-Don Mills                         6    6     6
# ...                                     ...  ...   ...
# Wychwood                                  5    5     5
# Yonge-Eglinton                            3    3     3
# Yonge-St.Clair                            1    1     1
# York University Heights                  11   11    11
# Yorkdale-Glen Park                       13   13    13
#
# [134 rows x 3 columns]

# %%
# one hot encoding
homicide_onehot = pd.get_dummies(filtered_columns[['Homicide_Type']], prefix="", prefix_sep="")

# %%
homicide_onehot['Neighborhood'] = filtered_columns['Neighborhood']

# %%
fixed_columns = [homicide_onehot.columns[-1]] + list(homicide_onehot.columns[:-1])
homicide_onehot = homicide_onehot[fixed_columns]

homicide_onehot.head()
# Out:
#                         Neighborhood  Other  Shooting  Stabbing
# 0  Waterfront Communities-The Island      0         1         0
# 1                   Victoria Village      0         0         1
# 2                   Victoria Village      0         0         1
# 3                            Malvern      0         1         0
# 4                  High Park-Swansea      1         0         0

# %%
homicide_grouped = homicide_onehot.groupby('Neighborhood').mean().reset_index()

# %%
homicide_grouped
# Out:
#                      Neighborhood     Other  Shooting  Stabbing
# 0                 Agincourt North  0.600000  0.200000  0.200000
# 1    Agincourt South-Malvern West  0.166667  0.833333  0.000000
# 2                       Alderwood  0.000000  0.833333  0.166667
# 3                           Annex  0.142857  0.285714  0.571429
# 4               Banbury-Don Mills  0.166667  0.500000  0.333333
# ..                            ...       ...       ...       ...
# 129                      Wychwood  0.400000  0.400000  0.200000
# 130                Yonge-Eglinton  0.333333  0.666667  0.000000
# 131                Yonge-St.Clair  0.000000  0.000000  1.000000
# 132       York University Heights  0.272727  0.363636  0.363636
# 133            Yorkdale-Glen Park  0.153846  0.846154  0.000000
#
# [134 rows x 4 columns]

# %%
num_top_venues = 5

for hood in homicide_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = homicide_grouped[homicide_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agincourt North----
#       venue  freq
# 0     Other   0.6
# 1  Shooting   0.2
# 2  Stabbing   0.2
#
#
# ----Agincourt South-Malvern West----
#       venue  freq
# 0  Shooting  0.83
# 1     Other  0.17
# 2  Stabbing  0.00
#
#
# ----Alderwood----
#       venue  freq
# 0  Shooting  0.83
# 1  Stabbing  0.17
# 2     Other  0.00
#
#
# ----Annex----
#       venue  freq
# 0  Stabbing  0.57
# 1  Shooting  0.29
# 2     Other  0.14
#
#
# ----Banbury-Don Mills----
#       venue  freq
# 0  Shooting  0.50
# 1  Stabbing  0.33
# 2     Other  0.17
#
#
# ----Bathurst Manor----
#       venue  freq
# 0  Stabbing   1.0
# 1     Other   0.0
# 2  Shooting   0.0
#
#
# ----Bay Street Corridor----
#       venue  freq
# 0  Shooting   0.5
# 1  Stabbing   0.5
# 2     Other   0.0
#
#
# ----Bayview Village----
#       venue  freq
# 0  Shooting   0.5
# 1  Stabbing   0.5
# 2     Other   0.0
#
#
# ----Bayview Woods-Steeles----
#       venue  freq
# 0  Shooting   1.0
# 1     Other   0.0
# 2  Stabbing   0.0
#
#
# ----Bedford Park-Nortown----
#       venue  freq
# 0     Other  0.67
# 1  Stabbing  0.33
# 2  Shooting  0.00
#
#
# ----Beechborough-Greenbrook----
#       venue  freq
# 0  Shooting  0.67
# 1  Stabbing  0.33
# 2     Other  0.00
#
#
# ----Bendale----
#       venue  freq
# 0  Stabbing  0.44
# 1  Shooting  0.33
# 2     Other  0.22
#
#
# ----Birchcliffe-Cliffside----
#       venue  freq
# 0  Stabbing  0.67
# 1     Other  0.17
# 2  Shooting  0.17
#
#
# ----Black Creek----
#       venue  freq
# 0  Shooting  0.90
# 1     Other  0.05
# 2  Stabbing  0.05
#
#
# ----Blake-Jones----
#       venue  freq
# 0     Other  0.33
# 1  Shooting  0.33
# 2  Stabbing  0.33
#
#
# ----Briar Hill-Belgravia----
#       venue  freq
# 0  Shooting  0.50
# 1     Other  0.33
# 2  Stabbing  0.17
#
#
# ----Broadview North----
#       venue  freq
# 0  Stabbing  0.67
# 1     Other  0.33
# 2  Shooting  0.00
#
#
# ----Brookhaven-Amesbury----
#       venue  freq
# 0     Other  0.75
# 1  Shooting  0.25
# 2  Stabbing  0.00
#
#
# ----Cabbagetown-South St.James Town----
#       venue  freq
# 0  Shooting  0.55
# 1  Stabbing  0.27
# 2     Other  0.18
#
#
# ----Caledonia-Fairbank----
#       venue  freq
# 0     Other   0.5
# 1  Stabbing   0.5
# 2  Shooting   0.0
#
#
# ----Casa Loma----
#       venue  freq
# 0  Stabbing   1.0
# 1     Other   0.0
# 2  Shooting   0.0
#
#
# ----Centennial Scarborough----
#       venue  freq
# 0     Other   0.5
# 1  Shooting   0.5
# 2  Stabbing   0.0
#
#
# ----Church-Yonge Corridor----
#       venue  freq
# 0     Other  0.50
# 1  Shooting  0.33
# 2  Stabbing  0.17
#
#
# ----Clairlea-Birchmount----
#       venue  freq
# 0     Other  0.53
# 1  Shooting  0.27
# 2  Stabbing  0.20
#
#
# ----Clanton Park----
#       venue  freq
# 0     Other  0.50
# 1  Shooting  0.33
# 2  Stabbing  0.17
#
#
# ----Cliffcrest----
#       venue  freq
# 0  Stabbing   0.6
# 1     Other   0.2
# 2  Shooting   0.2
#
#
# ----Corso Italia-Davenport----
#       venue  freq
# 0     Other   1.0
# 1  Shooting   0.0
# 2  Stabbing   0.0
#
#
# ----Danforth----
#       venue  freq
# 0  Shooting   0.5
# 1  Stabbing   0.3
# 2     Other   0.2
#
#
# ----Don Valley Village----
#       venue  freq
# 0     Other   0.6
# 1  Shooting   0.2
# 2  Stabbing   0.2
#
#
# ----Dorset Park----
#       venue  freq
# 0  Shooting  0.64
# 1     Other  0.18
# 2  Stabbing  0.18
#
#
# ----Dovercourt-Wallace Emerson-Junction----
#       venue  freq
# 0     Other  0.50
# 1  Shooting  0.27
# 2  Stabbing  0.23
#
#
# ----Downsview-Roding-CFB----
#       venue  freq
# 0  Shooting  0.62
# 1  Stabbing  0.31
# 2     Other  0.08
#
#
# ----Dufferin Grove----
#       venue  freq
# 0  Stabbing  0.67
# 1  Shooting  0.33
# 2     Other  0.00
#
#
# ----East End-Danforth----
#       venue  freq
# 0  Shooting  0.67
# 1  Stabbing  0.22
# 2     Other  0.11
#
#
# ----Edenbridge-Humber Valley----
#       venue  freq
# 0  Shooting   1.0
# 1     Other   0.0
# 2  Stabbing   0.0
#
#
# ----Eglinton East----
#       venue  freq
# 0  Shooting   0.7
# 1  Stabbing   0.2
# 2     Other   0.1
#
#
# ----Elms-Old Rexdale----
#       venue  freq
# 0  Shooting  0.88
# 1     Other  0.12
# 2  Stabbing  0.00
#
#
# ----Englemount-Lawrence----
#       venue  freq
# 0  Shooting  0.83
# 1  Stabbing  0.17
# 2     Other  0.00
#
#
# ----Eringate-Centennial-West Deane----
#       venue  freq
# 0     Other   0.5
# 1  Shooting   0.5
# 2  Stabbing   0.0
#
#
# ----Etobicoke West Mall----
#       venue  freq
# 0  Shooting   0.5
# 1  Stabbing   0.5
# 2     Other   0.0
#
#
# ----Flemingdon Park----
#       venue  freq
# 0  Shooting   0.6
# 1  Stabbing   0.3
# 2     Other   0.1
#
#
# ----Forest Hill North----
#       venue  freq
# 0     Other   1.0
# 1  Shooting   0.0
# 2  Stabbing   0.0
#
#
# ----Glenfield-Jane Heights----
#       venue  freq
# 0  Shooting  0.69
# 1  Stabbing  0.21
# 2     Other  0.10
#
#
# ----Greenwood-Coxwell----
#       venue  freq
# 0     Other  0.67
# 1  Shooting  0.33
# 2  Stabbing  0.00
#
#
# ----Guildwood----
#       venue  freq
# 0  Stabbing   1.0
# 1     Other   0.0
# 2  Shooting   0.0
#
#
# ----HUmber Summit----
#       venue  freq
# 0  Shooting   1.0
# 1     Other   0.0
# 2  Stabbing   0.0
#
#
# ----Henry Farm----
#       venue  freq
# 0  Shooting  0.67
# 1  Stabbing  0.33
# 2     Other  0.00
#
#
# ----High Park North----
#       venue  freq
# 0     Other  0.67
# 1  Stabbing  0.33
# 2  Shooting  0.00
#
#
# ----High Park-Swansea----
#       venue  freq
# 0     Other   0.4
# 1  Shooting   0.4
# 2  Stabbing   0.2
#
#
# ----Highland Creek----
#       venue  freq
# 0  Shooting  0.50
# 1     Other  0.25
# 2  Stabbing  0.25
#
#
# ----Hillcrest Village----
#       venue  freq
# 0  Shooting  0.50
# 1     Other  0.25
# 2  Stabbing  0.25
#
#
# ----Humber Heights-Westmount----
#       venue  freq
# 0  Shooting  0.86
# 1  Stabbing  0.14
# 2     Other  0.00
#
#
# ----Humber Summit----
#       venue  freq
# 0  Shooting  0.87
# 1     Other  0.07
# 2  Stabbing  0.07
#
#
# ----Humbermede----
#       venue  freq
# 0  Shooting  0.83
# 1  Stabbing  0.17
# 2     Other  0.00
#
#
# ----Humewood-Cedarvale----
#       venue  freq
# 0     Other  0.67
# 1  Shooting  0.33
# 2  Stabbing  0.00
#
#
# ----Ionview----
#       venue  freq
# 0     Other   0.5
# 1  Shooting   0.5
# 2  Stabbing   0.0
#
#
# ----Islington-City Centre West----
#       venue  freq
# 0  Shooting  0.45
# 1  Stabbing  0.36
# 2     Other  0.18
#
#
# ----Junction Area----
#       venue  freq
# 0     Other  0.43
# 1  Shooting  0.43
# 2  Stabbing  0.14
#
#
# ----Keelesdale-Eglinton West----
#       venue  freq
# 0  Shooting  0.67
# 1     Other  0.17
# 2  Stabbing  0.17
#
#
# ----Kennedy Park----
#       venue  freq
# 0  Stabbing  0.71
# 1     Other  0.14
# 2  Shooting  0.14
#
#
# ----Kensington-Chinatown----
#       venue  freq
# 0  Shooting  0.58
# 1     Other  0.32
# 2  Stabbing  0.11
#
#
# ----Kingsview Village-The Westway----
#       venue  freq
# 0  Shooting  0.79
# 1  Stabbing  0.21
# 2     Other  0.00
#
#
# ----Kingsway South----
#       venue  freq
# 0  Stabbing   1.0
# 1     Other   0.0
# 2  Shooting   0.0
#
#
# ----L'Amoreaux----
#       venue  freq
# 0  Shooting  0.62
# 1  Stabbing  0.31
# 2     Other  0.08
#
#
# ----Lambton Baby Point----
#       venue  freq
# 0  Shooting   0.8
# 1  Stabbing   0.2
# 2     Other   0.0
#
#
# ----Lansing-Westgate----
#       venue  freq
# 0     Other  0.77
# 1  Shooting  0.15
# 2  Stabbing  0.08
#
#
# ----Lawrence Park North----
#       venue  freq
# 0  Shooting   0.5
# 1  Stabbing   0.5
# 2     Other   0.0
#
#
# ----Leaside-Bennington----
#       venue  freq
# 0     Other   0.5
# 1  Shooting   0.5
# 2  Stabbing   0.0
#
#
# ----Little Portugal----
#       venue  freq
# 0     Other  0.43
# 1  Shooting  0.29
# 2  Stabbing  0.29
#
#
# ----Malvern----
#       venue  freq
# 0  Shooting  0.62
# 1     Other  0.38
# 2  Stabbing  0.00
#
#
# ----Maple Leaf----
#       venue  freq
# 0  Shooting   1.0
# 1     Other   0.0
# 2  Stabbing   0.0
#
#
# ----Markland Wood----
#       venue  freq
# 0  Stabbing   0.6
# 1     Other   0.2
# 2  Shooting   0.2
#
#
# ----Milliken----
#       venue  freq
# 0     Other  0.33
# 1  Shooting  0.33
# 2  Stabbing  0.33
#
#
# ----Mimico (includes Humber Bay Shores----
#       venue  freq
# 0     Other   0.5
# 1  Shooting   0.5
# 2  Stabbing   0.0
#
#
# ----Morningside----
#       venue  freq
# 0  Shooting  0.46
# 1  Stabbing  0.38
# 2     Other  0.15
#
#
# ----Moss Park----
#       venue  freq
# 0     Other  0.41
# 1  Shooting  0.38
# 2  Stabbing  0.21
#
#
# ----Mount Dennis----
#       venue  freq
# 0  Shooting  0.83
# 1     Other  0.08
# 2  Stabbing  0.08
#
#
# ----Mount Olive-Silverstone-Jamestown----
#       venue  freq
# 0  Shooting  0.74
# 1  Stabbing  0.16
# 2     Other  0.10
#
#
# ----Mount Pleasant East----
#       venue  freq
# 0     Other   0.5
# 1  Shooting   0.5
# 2  Stabbing   0.0
#
#
# ----Mount Pleasant West----
#       venue  freq
# 0     Other  0.67
# 1  Shooting  0.33
# 2  Stabbing  0.00
#
#
# ----New Toronto----
#       venue  freq
# 0     Other  0.43
# 1  Shooting  0.29
# 2  Stabbing  0.29
#
#
# ----Newtonbrook East----
#       venue  freq
# 0  Stabbing  0.67
# 1     Other  0.33
# 2  Shooting  0.00
#
#
# ----Newtonbrook West----
#       venue  freq
# 0     Other   0.5
# 1  Stabbing   0.5
# 2  Shooting   0.0
#
#
# ----Niagara----
#       venue  freq
# 0  Shooting  0.67
# 1     Other  0.20
# 2  Stabbing  0.13
#
#
# ----North Riverdale----
#       venue  freq
# 0     Other  0.67
# 1  Shooting  0.33
# 2  Stabbing  0.00
#
#
# ----North St.James Town----
#       venue  freq
# 0  Shooting   0.4
# 1  Stabbing   0.4
# 2     Other   0.2
#
#
# ----O'Connor-Parkview----
#       venue  freq
# 0  Stabbing   0.5
# 1     Other   0.4
# 2  Shooting   0.1
#
#
# ----Oakridge----
#       venue  freq
# 0     Other  0.50
# 1  Shooting  0.33
# 2  Stabbing  0.17
#
#
# ----Oakwood Village----
#       venue  freq
# 0  Shooting  0.78
# 1     Other  0.11
# 2  Stabbing  0.11
#
#
# ----Old East York----
#       venue  freq
# 0  Shooting   0.4
# 1  Stabbing   0.4
# 2     Other   0.2
#
#
# ----Palmerston-Little Italy----
#       venue  freq
# 0  Shooting   1.0
# 1     Other   0.0
# 2  Stabbing   0.0
#
#
# ----Parkwoods-Donalda----
#       venue  freq
# 0  Stabbing  0.50
# 1     Other  0.33
# 2  Shooting  0.17
#
#
# ----Pelmo Park-Humberlea----
#       venue  freq
# 0  Shooting  0.67
# 1     Other  0.33
# 2  Stabbing  0.00
#
#
# ----Playter Estates-Danforth----
#       venue  freq
# 0  Shooting   0.6
# 1     Other   0.2
# 2  Stabbing   0.2
#
#
# ----Pleasant View----
#       venue  freq
# 0     Other   1.0
# 1  Shooting   0.0
# 2  Stabbing   0.0
#
#
# ----Princess-Rosethorn----
#       venue  freq
# 0  Shooting   1.0
# 1     Other   0.0
# 2  Stabbing   0.0
#
#
# ----Regent Park----
#       venue  freq
# 0  Shooting  0.75
# 1     Other  0.25
# 2  Stabbing  0.00
#
#
# ----Rexdale-Kipling----
#       venue  freq
# 0  Shooting  0.50
# 1     Other  0.33
# 2  Stabbing  0.17
#
#
# ----Rockcliffe-Smythe----
#       venue  freq
# 0  Shooting  0.47
# 1  Stabbing  0.33
# 2     Other  0.20
#
#
# ----Roncesvalles----
#       venue  freq
# 0     Other   0.8
# 1  Shooting   0.2
# 2  Stabbing   0.0
#
#
# ----Rosedale-Moore Park----
#       venue  freq
# 0     Other   1.0
# 1  Shooting   0.0
# 2  Stabbing   0.0
#
#
# ----Rouge----
#       venue  freq
# 0  Shooting  0.81
# 1  Stabbing  0.19
# 2     Other  0.00
#
#
# ----Rustic----
#       venue  freq
# 0  Shooting  0.78
# 1     Other  0.11
# 2  Stabbing  0.11
#
#
# ----Scarborough Village----
#       venue  freq
# 0  Shooting  0.50
# 1     Other  0.36
# 2  Stabbing  0.14
#
#
# ----South Parkdale----
#       venue  freq
# 0  Shooting  0.62
# 1     Other  0.23
# 2  Stabbing  0.15
#
#
# ----South Riverdale----
#       venue  freq
# 0  Shooting  0.50
# 1  Stabbing  0.32
# 2     Other  0.18
#
#
# ----St.Andrew-Windfields----
#       venue  freq
# 0     Other  0.50
# 1  Shooting  0.25
# 2  Stabbing  0.25
#
#
# ----Steeles----
#       venue  freq
# 0     Other  0.75
# 1  Stabbing  0.25
# 2  Shooting  0.00
#
#
# ----Stonegate-Queensway----
#       venue  freq
# 0  Stabbing  0.67
# 1     Other  0.33
# 2  Shooting  0.00
#
#
# ----Tam O'Shanter-Sullivan----
#       venue  freq
# 0  Stabbing  0.50
# 1  Shooting  0.38
# 2     Other  0.12
#
#
# ----Taylor-Massey----
#       venue  freq
# 0  Shooting  0.57
# 1     Other  0.43
# 2  Stabbing  0.00
#
#
# ----Thistletown-Beaumond Heights----
#       venue  freq
# 0  Shooting   0.8
# 1     Other   0.2
# 2  Stabbing   0.0
#
#
# ----Thorncliffe Park----
#       venue  freq
# 0     Other  0.50
# 1  Stabbing  0.42
# 2  Shooting  0.08
#
#
# ----Trinity-Bellwoods----
#       venue  freq
# 0     Other   0.5
# 1  Shooting   0.5
# 2  Stabbing   0.0
#
#
# ----University----
#       venue  freq
# 0  Shooting   0.4
# 1  Stabbing   0.4
# 2     Other   0.2
#
#
# ----Victoria Village----
#       venue  freq
# 0  Shooting   0.5
# 1  Stabbing   0.4
# 2     Other   0.1
#
#
# ----Waterfront Communities-The Island----
#       venue  freq
# 0  Shooting  0.71
# 1     Other  0.24
# 2  Stabbing  0.06
#
#
# ----West Hill----
#       venue  freq
# 0  Shooting  0.54
# 1  Stabbing  0.31
# 2     Other  0.15
#
#
# ----West Humber-Clairville----
#       venue  freq
# 0  Shooting  0.75
# 1     Other  0.19
# 2  Stabbing  0.06
#
#
# ----Westminster-Branson----
#       venue  freq
# 0  Shooting   1.0
# 1     Other   0.0
# 2  Stabbing   0.0
#
#
# ----Weston----
#       venue  freq
# 0  Shooting  0.58
# 1  Stabbing  0.26
# 2     Other  0.16
#
#
# ----Weston-Pellam Park----
#       venue  freq
# 0     Other  0.38
# 1  Shooting  0.38
# 2  Stabbing  0.25
#
#
# ----Wexford/Maryvale----
#       venue  freq
# 0     Other   0.4
# 1  Shooting   0.4
# 2  Stabbing   0.2
#
#
# ----Willowdale East----
#       venue  freq
# 0     Other  0.33
# 1  Shooting  0.33
# 2  Stabbing  0.33
#
#
# ----Willowdale West----
#       venue  freq
# 0     Other   0.5
# 1  Shooting   0.5
# 2  Stabbing   0.0
#
#
# ----Willowridge-Martingrove-Richview----
#       venue  freq
# 0     Other  0.50
# 1  Stabbing  0.33
# 2  Shooting  0.17
#
#
# ----Woburn----
#       venue  freq
# 0  Shooting  0.48
# 1     Other  0.33
# 2  Stabbing  0.19
#
#
# ----Woodbine Corridor----
#       venue  freq
# 0  Shooting  0.57
# 1     Other  0.29
# 2  Stabbing  0.14
#
#
# ----Woodbine-Lumsden----
#       venue  freq
# 0  Stabbing  0.67
# 1     Other  0.33
# 2  Shooting  0.00
#
#
# ----Wychwood----
#       venue  freq
# 0     Other   0.4
# 1  Shooting   0.4
# 2  Stabbing   0.2
#
#
# ----Yonge-Eglinton----
#       venue  freq
# 0  Shooting  0.67
# 1     Other  0.33
# 2  Stabbing  0.00
#
#
# ----Yonge-St.Clair----
#       venue  freq
# 0  Stabbing   1.0
# 1     Other   0.0
# 2  Shooting   0.0
#
#
# ----York University Heights----
#       venue  freq
# 0  Shooting  0.36
# 1  Stabbing  0.36
# 2     Other  0.27
#
#
# ----Yorkdale-Glen Park----
#       venue  freq
# 0  Shooting  0.85
# 1     Other  0.15
# 2  Stabbing  0.00

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 3

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_homicides_sorted = pd.DataFrame(columns=columns)
neighborhoods_homicides_sorted['Neighborhood'] = homicide_grouped['Neighborhood']

for ind in np.arange(homicide_grouped.shape[0]):
    neighborhoods_homicides_sorted.iloc[ind, 1:] = return_most_common_venues(homicide_grouped.iloc[ind, :], num_top_venues)

neighborhoods_homicides_sorted.head(10)
# Out:
#                    Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0               Agincourt North                 Other              Stabbing
# 1  Agincourt South-Malvern West              Shooting                 Other
# 2                     Alderwood              Shooting              Stabbing
# 3                         Annex              Stabbing              Shooting
# 4             Banbury-Don Mills              Shooting              Stabbing
# 5                Bathurst Manor              Stabbing              Shooting
# 6           Bay Street Corridor              Stabbing              Shooting
# 7               Bayview Village              Stabbing              Shooting
# 8         Bayview Woods-Steeles              Shooting              Stabbing
# 9          Bedford Park-Nortown                 Other              Stabbing
#
#   3rd Most Common Venue
# 0              Shooting
# 1              Stabbing
# 2                 Other
# 3                 Other
# 4                 Other
# 5                 Other
# 6                 Other
# 7                 Other
# 8                 Other
# 9              Shooting

# %%
# set number of clusters
kclusters = 3

homicide_grouped_clustering = homicide_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(homicide_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 1, 1, 2, 1, 2, 1, 1, 1, 0])

# %%
# add clustering labels
neighborhoods_homicides_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

homicide_merged = filtered_columns

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
homicide_merged = homicide_merged.join(neighborhoods_homicides_sorted.set_index('Neighborhood'), on='Neighborhood')

homicide_merged.head() # check the last columns!
# Out:
#                         Neighborhood Homicide_Type        Lat       Long  \
# 0  Waterfront Communities-The Island      Shooting  43.648640 -79.386620
# 1                   Victoria Village      Stabbing  43.715988 -79.304939
# 2                   Victoria Village      Stabbing  43.715988 -79.304939
# 3                            Malvern      Shooting  43.809391 -79.228691
# 4                  High Park-Swansea         Other  43.649334 -79.484482
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               1              Shooting                 Other
# 1               1              Shooting              Stabbing
# 2               1              Shooting              Stabbing
# 3               1              Shooting                 Other
# 4               0              Shooting                 Other
#
#   3rd Most Common Venue
# 0              Stabbing
# 1                 Other
# 2                 Other
# 3              Stabbing
# 4              Stabbing

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
# create map
map_clusters = folium.Map(location=[43.6532, -79.3832], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(homicide_merged['Lat'], homicide_merged['Long'], homicide_merged['Neighborhood'], homicide_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
